# %% [markdown]
# # Estadística Aplicada
# ## Raúl Flores Robles 1838148
# ### 3ra Sesión

# %%
import numpy as np
import pandas as pd

# %%
alumno1 = ['Juan','Lopez',23]
alumno2 = ['Raul','Lopez',15]
alumno3 = ['John','Lara',18]
alumno4 = ['Xime','Lira',22]
alumno5 = ['Ale','Lugo',26]

# %%
estadistica = [alumno1,alumno2,alumno3,alumno4,alumno5]

# %%
estadistica = pd.DataFrame(estadistica,columns=['Nombre','Apellido','Edad'])
estadistica
# Out:
#   Nombre Apellido  Edad
# 0   Juan    Lopez    23
# 1   Raul    Lopez    15
# 2   John     Lara    18
# 3   Xime     Lira    22
# 4    Ale     Lugo    26

# %%
estadistica.columns
# Out:
# Index(['Nombre', 'Apellido', 'Edad'], dtype='object')

# %%
estadistica.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
estadistica.shape
# Out:
# (5, 3)

# %%
estadistica.describe()
# Out:
#            Edad
# count   5.00000
# mean   20.80000
# std     4.32435
# min    15.00000
# 25%    18.00000
# 50%    22.00000
# 75%    23.00000
# max    26.00000

# %%
estadistica['Edad en días'] = estadistica['Edad']*365

# %%
estadistica
# Out:
#   Nombre Apellido  Edad  Edad en días
# 0   Juan    Lopez    23          8395
# 1   Raul    Lopez    15          5475
# 2   John     Lara    18          6570
# 3   Xime     Lira    22          8030
# 4    Ale     Lugo    26          9490

# %%
estadistica['Origen'] = ['Apodaca','San Pedro','Guadalupe','Salinas','Cadereyta']

# %%
estadistica
# Out:
#   Nombre Apellido  Edad  Edad en días     Origen
# 0   Juan    Lopez    23          8395    Apodaca
# 1   Raul    Lopez    15          5475  San Pedro
# 2   John     Lara    18          6570  Guadalupe
# 3   Xime     Lira    22          8030    Salinas
# 4    Ale     Lugo    26          9490  Cadereyta

# %%
estadistica['Edad'].mean()
# Out:
# 20.8

# %%
round(estadistica['Edad'].std(ddof=1),2)
# Out:
# 4.32

# %%
estadistica.dtypes
# Out:
# Nombre          object
# Apellido        object
# Edad             int64
# Edad en días     int64
# Origen          object
# dtype: object

# %%
estadistica.count()
# Out:
# Nombre          5
# Apellido        5
# Edad            5
# Edad en días    5
# Origen          5
# dtype: int64

# %%
estadistica.sort_values('Apellido',ascending=True)
# Out:
#   Nombre Apellido  Edad  Edad en días     Origen
# 2   John     Lara    18          6570  Guadalupe
# 3   Xime     Lira    22          8030    Salinas
# 0   Juan    Lopez    23          8395    Apodaca
# 1   Raul    Lopez    15          5475  San Pedro
# 4    Ale     Lugo    26          9490  Cadereyta

# %%
estadistica.sort_values(['Apellido','Nombre'],ascending=[True,True])
# Out:
#   Nombre Apellido  Edad  Edad en días     Origen
# 2   John     Lara    18          6570  Guadalupe
# 3   Xime     Lira    22          8030    Salinas
# 0   Juan    Lopez    23          8395    Apodaca
# 1   Raul    Lopez    15          5475  San Pedro
# 4    Ale     Lugo    26          9490  Cadereyta
