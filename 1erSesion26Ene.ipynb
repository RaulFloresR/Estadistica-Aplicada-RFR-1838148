# %% [markdown]
# # Estadistica Aplicada
# ## Raul Flores Robles
# ### Primer Sesion 26 de enero
# **Negritas**

# %% [markdown]
# También admite codigo de Latex.
# Este es un ejemplo de una ecuación:
# $Y_i=a+b x_i+\epsilon_i$

# %%
variable1 = 1.34

# %%
variable1
# Out:
# 1.34

# %%
variable2 = 2

# %%
variable2
# Out:
# 2

# %%
variable3 = 'A'

# %%
variable3
# Out:
# 'A'

# %%
type(variable1)
# Out:
# float

# %%
type(variable2)
# Out:
# int

# %%
type(variable3)
# Out:
# str

# %%
variable2_decimal = float(variable2)

# %%
type(variable2_decimal)
# Out:
# float

# %%
print(variable3)
# Out:
# A

# %%
print(variable3,variable2)
# Out:
# A 2

# %%
print('Esta es la letra a mayúscula',variable3)
# Out:
# Esta es la letra a mayúscula A

# %%
print('Este es el dos entero',variable2)
# Out:
# Este es el dos entero 2

# %%
print(f'Este es el dos decimal {variable2_decimal}')
# Out:
# Este es el dos decimal 2.0
