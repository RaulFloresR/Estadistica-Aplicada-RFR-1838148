# %% [markdown]
# # Estadistica aplicada
# ## Raúl Flores Robles 1838148
# ### Series de tiempo (enfoque estocástico)
# 28 abr de 2023

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import adfuller #Prueba de dickey-fuller

# %%
procesos= pd.read_excel('procesos_estacionariosG41.xlsx')

# %%
procesos
# Out:
#      ruido_blanco      ar_1      ma_1   arma_11
# 0       -0.416291  0.783709  1.583709  0.483709
# 1       -1.200566 -0.730341  0.591288 -1.178554
# 2        0.244522 -0.193683  1.644239 -0.850094
# 3       -0.099132 -0.215342  2.023129 -0.366749
# 4        0.148857  0.019652  2.099291 -0.062772
# ..            ...       ...       ...       ...
# 995     -0.670759 -0.892074  1.499536 -0.822315
# 996      1.052115  0.516871  2.716735  0.366817
# 997     -1.048340 -0.738217  1.477718 -0.388778
# 998      0.265279 -0.177651  1.741109 -0.402391
# 999     -1.091242 -1.197833  1.041397 -1.147637
#
# [1000 rows x 4 columns]

# %% [markdown]
# Primero analizaremos el ruido blanco (white noise/ proceso aleatorio puro)

# %%
procesos['ruido_blanco'].plot(color='black',linewidth=0.3)
plt.xlim(0,1000)
plt.xlabel('Tiempo')
plt.title('Ruido Blanco')
plt.savefig('ruido_blanco.jpg')

# %% [markdown]
# 1. Determinar si la serie (ruido blanco) es estacionaria con una prueba de raiz unitaria

# %%
dickeyfuller1= adfuller(procesos['ruido_blanco'])
alpha = 0.05

if dickeyfuller1[1] < alpha:
    print('Se rechaza H0, la serie es estacionaria')
else:
    print('No se rechaza H0, la serie es no estacionaria')
# Out:
# Se rechaza H0, la serie es estacionaria

# %% [markdown]
# 2. Determinar que tipo de proceso estacionario es con las gráficas de autocorrelación ACF y autocorrelación parcial PACF

# %%
fig, ax = plt.subplots(1,2,figsize=(12,4))
## subgrafica 0 
plot_acf(procesos['ruido_blanco'],zero=False, ax=ax[0],title='Función de autocorrelación ACF')
ax[0].set_ylim(-1,1)
##subgrafica 1
plot_pacf(procesos['ruido_blanco'],zero=False, ax=ax[1],title='Función de autocorrelación parcial PACF')
ax[1].set_ylim(-1,1)
plt.savefig('correl_ruidoblanco.jpg');

# %% [markdown]
# AR(1)

# %%
procesos['ar_1'].plot(color='black',linewidth=0.3)
plt.xlim(0,1000)
plt.xlabel('Tiempo')
plt.title('AR(1)')
plt.savefig('ar_1.jpg')

# %%
dickeyfuller2= adfuller(procesos['ar_1'])
alpha = 0.05

if dickeyfuller2[1] < alpha:
    print('Se rechaza H0, la serie es estacionaria')
else:
    print('No se rechaza H0, la serie es no estacionaria')
# Out:
# Se rechaza H0, la serie es estacionaria

# %%
fig, ax = plt.subplots(1,2,figsize=(12,4))
## subgrafica 0 
plot_acf(procesos['ar_1'],zero=False, ax=ax[0],title='Función de autocorrelación ACF')
ax[0].set_ylim(-1,1)
##subgrafica 1
plot_pacf(procesos['ar_1'],zero=False, ax=ax[1],title='Función de autocorrelación parcial PACF');
ax[1].set_ylim(-1,1)
plt.savefig('correl_ar1.jpg')
